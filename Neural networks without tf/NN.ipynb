# %%
import math
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
X = df.iloc[:,0:3].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
coef1 =1.136335 
coef2= 0.7236735
bias =1.6098249

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
sigmoid(4)
# Out:
# 0.9820137900379085

# %%
def prediction(age , Salary):
    sum = coef1*age + coef2*Salary +bias
    return sigmoid(sum)

prediction(2,400)
# Out:
# 1.0

# %%
epsilon= 1e-15

# %%
def Binary_Cross_Entropy(y_true,y_pred):
    y_pred_new= [min(i,1-epsilon) for i in y_pred]
    y_pred_new=[max(i,epsilon) for i in y_pred_new]
    y_pred_new= np.array(y_pred_new)
    return -np.mean(y_true*np.log(y_pred_new)+(1-y_true)*np.log(1-y_pred_new))

# %%
def gradient_descent(age,Salary, epoch, y_true):
    w1=w2=0
    bias=0
    rate = 0.1 #alpha
    n = len(age)
    for i in range(epoch):
        weighted_sum = w1*age + w2*Salary+bias
        y_pred = sigmoid(weighted_sum)
        
        loss = Binary_Cross_Entropy(y_true, y_pred)
        #derivatives
        w1d = (1/n)* np.dot(np.transpose(age) ,(y_pred -y_true))
        w2d = (1/n)* np.dot(np.transpose(Salary) ,(y_pred -y_true))
        
        biasd= np.mean(y_pred - y_true)
        w1= w1 - rate *w1d
        w2 =w2 -rate*w2d
        bias = bias -rate*biasd
        print(f"Epoch{i}: w1={w1} ,w2 ={w2},  bias ={bias}, loss = {loss}")
    return w1,w2,bias

# %%
class NN:
    def __init__n(self):
        self.w1 = 1
        self.w2 = 1
        self.bias =1
    def gradient_descent(self,age,Salary, epoch, y_true):
        w1 = w2 = 1
        bias = 0
        rate = 0.1 #alpha
        n = len(age)
        for i in range(epoch):
            weighted_sum = w1*age + w2*Salary+bias
            y_pred = sigmoid(weighted_sum)

            loss = Binary_Cross_Entropy(y_true, y_pred)
            #derivatives
            w1d = (1/n)* np.dot(np.transpose(age) ,(y_pred -y_true))
            w2d = (1/n)* np.dot(np.transpose(Salary) ,(y_pred -y_true))

            biasd= np.mean(y_pred - y_true)
            w1= w1 - rate *w1d
            w2 =w2 -rate*w2d
            bias = bias -rate*biasd
            print(f"Epoch{i}: w1={w1} ,w2 ={w2},  bias ={bias}, loss = {loss}")
        return w1,w2,bias
    
    
    
    def fit(self, X,y,epochs):
        self.w1,self.w2,self.bias=self.gradient_descent(X_train[:,0],X_train[:,1], 1000, y_train)
        print(f"Final weights and bias: w1: {self.w1}, w2: {self.w2}, bias: {self.bias}")
    def predict(self,X,y):
        weighted_sum =  self.w1*X_test[:, 0] + self.w2*X_test[:,1] + self.bias
        return sigmoid(weighted_sum)

# %%
myNN = NN()
myNN.fit(X_train ,y_train,1000)
# Out:
# Epoch0: w1=1.0084765036717385 ,w2 =0.9977136170244656,  bias =-0.011524216337075602, loss = 0.4665762767831227
# Epoch1: w1=1.0168374161139666 ,w2 =0.9954665059153363,  bias =-0.022849921525284193, loss = 0.4644942131884132
# Epoch2: w1=1.0250853873385968 ,w2 =0.9932588766376517,  bias =-0.03398116922681822, loss = 0.46247814222195577
# Epoch3: w1=1.0332229870454293 ,w2 =0.991090891570393,  bias =-0.04492192082841265, loss = 0.46052567183706367
# Epoch4: w1=1.0412527073085514 ,w2 =0.9889626683048134,  bias =-0.055676047649376295, loss = 0.4586345049018066
# Epoch5: w1=1.0491769651815732 ,w2 =0.9868742823081236,  bias =-0.06624733310532552, loss = 0.45680243513212987
# Epoch6: w1=1.0569981052222959 ,w2 =0.9848257694587004,  bias =-0.07663947482685986, loss = 0.4550273432111229
# Epoch7: w1=1.0647184019376792 ,w2 =0.9828171284586874,  bias =-0.08685608673268792, loss = 0.4533071930857272
# ...

# %%
myNN.predict(X_test,y_test)
# Out:
# array([0.11490855, 0.16583468, 0.19734168, 0.09036118, 0.09626007,
#        0.00733737, 0.01416597, 0.75282781, 0.0056329 , 0.50562089,
#        0.03512696, 0.02851763, 0.16027854, 0.37659899, 0.01544091,
#        0.34938861, 0.28494955, 0.01216865, 0.99002469, 0.04006497,
#        0.08787453, 0.9677647 , 0.27729232, 0.89061063, 0.00418608,
#        0.97628343, 0.07888555, 0.07700247, 0.1943579 , 0.15989866,
#        0.02022828, 0.2987785 , 0.93532147, 0.15147529, 0.01392585,
#        0.00330556, 0.01971544, 0.06406051, 0.0264187 , 0.5508975 ,
#        0.06709822, 0.28404741, 0.05919039, 0.03756901, 0.81744745,
#        0.02568226, 0.30583552, 0.93309142, 0.00831926, 0.8672994 ,
#        0.99138818, 0.03612419, 0.11865079, 0.43226511, 0.98243918,
#        0.3182978 , 0.08444658, 0.04278515, 0.48416006, 0.00320615,
#        0.01918509, 0.93662609, 0.00903308, 0.40325019, 0.0017079 ,
#        0.98312801, 0.03831924, 0.02568226, 0.21420073, 0.47148597,
# ...
